# %% [markdown]
# ###**Preparing the dataset**
#
# Prepare the dataset using Labelme annotation tool (for Instance segmentation) and LabelImg for object detection.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###**Installing Detectron2 on Colab**

# %%
# !python -m pip install pyyaml==5.1
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting pyyaml==5.1
#   Using cached PyYAML-5.1.tar.gz (274 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-499ek6is
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-499ek6is
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 4e80df1e58901557e2824ce3b488d30209a9be33
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.13.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.9.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (0.11.2)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (3.11.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (4.5.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.41.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)

# %%
import torch, detectron2
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
import matplotlib.pyplot as plt
import cv2
import os
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
from detectron2.engine import DefaultTrainer
from detectron2.utils.visualizer import ColorMode
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog

# %%
def get_data_dicts(directory, classes):
    dataset_dicts = []
    for filename in [file for file in os.listdir(directory) if file.endswith('.json')]:
        json_file = os.path.join(directory, filename)
        with open(json_file) as f:
            img_anns = json.load(f)

        record = {}

        filename = os.path.join(directory, img_anns["imagePath"])

        record["file_name"] = filename
        record["height"] = 600
        record["width"] = 800

        annos = img_anns["shapes"]
        objs = []
        for anno in annos:
            px = [a[0] for a in anno['points']] # x coord
            py = [a[1] for a in anno['points']] # y-coord
            poly = [(x, y) for x, y in zip(px, py)] # poly for segmentation
            poly = [p for x in poly for p in x]

            obj = {
                "bbox": [np.min(px), np.min(py), np.max(px), np.max(py)],
                "bbox_mode": BoxMode.XYXY_ABS,
                "segmentation": [poly],
                "category_id": classes.index(anno['label']),
                "iscrowd": 0
            }
            objs.append(obj)
        record["annotations"] = objs
        dataset_dicts.append(record)
    return dataset_dicts

# %%
classes = ['Arduino_Nano', 'ESP8266', 'Heltec_ESP32_Lora', 'Raspberry_Pi_3']

data_path = '/content/drive/MyDrive/microcontroller-segmentation/'

for d in ["train", "test"]:
  dataset_name = "category_" + d
  if dataset_name in DatasetCatalog.list():
    DatasetCatalog.remove(dataset_name)
    DatasetCatalog.register(
        dataset_name,
        lambda d=d: get_data_dicts(data_path+d, classes)
    )
    MetadataCatalog.get("category_"+ d).set(thing_classes=classes)

microcontroller_metadata  = MetadataCatalog.get("category_train")

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("category_train",)
cfg.DATASETS.TEST = ("")
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.0001
cfg.SOLVER.MAX_ITER = 1000
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 4

# %%
import json
import numpy as np
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
# Out:
# [10/08 01:12:57 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=16, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 4, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [10/08 01:12:58 d2.data.build]: Removed 0 images with no usable annotations. 142 images left.
# [10/08 01:12:58 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/08 01:12:58 d2.data.build]: Using training sampler TrainingSampler
# [10/08 01:12:58 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/08 01:12:58 d2.data.common]: Serializing 142 elements to byte tensors and concatenating them all ...
# [10/08 01:12:58 d2.data.common]: Serialized dataset takes 0.11 MiB
# WARNING [10/08 01:12:58 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [10/08 01:12:58 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (5, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (5,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (16, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (16,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (4, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}

# %%
trainer.train()
# Out:
# [10/08 01:13:03 d2.engine.train_loop]: Starting training from iteration 0
# [10/08 01:13:13 d2.utils.events]:  eta: 0:07:59  iter: 19  total_loss: 2.437  loss_cls: 1.595  loss_box_reg: 0.1596  loss_mask: 0.6919  loss_rpn_cls: 0.002978  loss_rpn_loc: 0.003813    time: 0.5175  last_time: 0.5570  data_time: 0.0170  last_data_time: 0.0057   lr: 9.9905e-06  max_mem: 2759M
# [10/08 01:13:23 d2.utils.events]:  eta: 0:07:50  iter: 39  total_loss: 2.126  loss_cls: 1.301  loss_box_reg: 0.135  loss_mask: 0.6836  loss_rpn_cls: 0.005273  loss_rpn_loc: 0.003153    time: 0.5045  last_time: 0.5189  data_time: 0.0094  last_data_time: 0.0134   lr: 1.998e-05  max_mem: 2759M
# [10/08 01:13:33 d2.utils.events]:  eta: 0:07:45  iter: 59  total_loss: 1.613  loss_cls: 0.8144  loss_box_reg: 0.1324  loss_mask: 0.6596  loss_rpn_cls: 0.009604  loss_rpn_loc: 0.003315    time: 0.5064  last_time: 0.4933  data_time: 0.0115  last_data_time: 0.0068   lr: 2.997e-05  max_mem: 2759M
# [10/08 01:13:44 d2.utils.events]:  eta: 0:07:38  iter: 79  total_loss: 1.211  loss_cls: 0.4267  loss_box_reg: 0.1342  loss_mask: 0.6373  loss_rpn_cls: 0.004518  loss_rpn_loc: 0.005878    time: 0.5074  last_time: 0.4799  data_time: 0.0142  last_data_time: 0.0204   lr: 3.9961e-05  max_mem: 2759M
# [10/08 01:13:53 d2.utils.events]:  eta: 0:07:23  iter: 99  total_loss: 0.9591  loss_cls: 0.2321  loss_box_reg: 0.1382  loss_mask: 0.5991  loss_rpn_cls: 0.006241  loss_rpn_loc: 0.003899    time: 0.5014  last_time: 0.4767  data_time: 0.0159  last_data_time: 0.0276   lr: 4.9951e-05  max_mem: 2763M
# [10/08 01:14:03 d2.utils.events]:  eta: 0:07:10  iter: 119  total_loss: 0.898  loss_cls: 0.1905  loss_box_reg: 0.1528  loss_mask: 0.5348  loss_rpn_cls: 0.005562  loss_rpn_loc: 0.004043    time: 0.4963  last_time: 0.4537  data_time: 0.0083  last_data_time: 0.0084   lr: 5.994e-05  max_mem: 2763M
# [10/08 01:14:13 d2.utils.events]:  eta: 0:07:01  iter: 139  total_loss: 0.8156  loss_cls: 0.1679  loss_box_reg: 0.1441  loss_mask: 0.4584  loss_rpn_cls: 0.001549  loss_rpn_loc: 0.003444    time: 0.4962  last_time: 0.5226  data_time: 0.0178  last_data_time: 0.0071   lr: 6.9931e-05  max_mem: 2763M
# [10/08 01:14:22 d2.utils.events]:  eta: 0:06:49  iter: 159  total_loss: 0.7434  loss_cls: 0.1614  loss_box_reg: 0.1519  loss_mask: 0.4186  loss_rpn_cls: 0.005316  loss_rpn_loc: 0.003837    time: 0.4927  last_time: 0.4615  data_time: 0.0075  last_data_time: 0.0062   lr: 7.9921e-05  max_mem: 2763M
# [10/08 01:14:32 d2.utils.events]:  eta: 0:06:39  iter: 179  total_loss: 0.668  loss_cls: 0.1532  loss_box_reg: 0.1415  loss_mask: 0.3613  loss_rpn_cls: 0.002523  loss_rpn_loc: 0.003918    time: 0.4929  last_time: 0.5296  data_time: 0.0089  last_data_time: 0.0062   lr: 8.991e-05  max_mem: 2763M
# [10/08 01:14:42 d2.utils.events]:  eta: 0:06:29  iter: 199  total_loss: 0.6179  loss_cls: 0.1531  loss_box_reg: 0.1734  loss_mask: 0.2722  loss_rpn_cls: 0.002896  loss_rpn_loc: 0.002764    time: 0.4933  last_time: 0.5767  data_time: 0.0145  last_data_time: 0.0081   lr: 9.9901e-05  max_mem: 2763M
# [10/08 01:14:53 d2.utils.events]:  eta: 0:06:21  iter: 219  total_loss: 0.6151  loss_cls: 0.1616  loss_box_reg: 0.1884  loss_mask: 0.2477  loss_rpn_cls: 0.001064  loss_rpn_loc: 0.003177    time: 0.4977  last_time: 0.5753  data_time: 0.0107  last_data_time: 0.0280   lr: 0.00010989  max_mem: 2763M
# [10/08 01:15:03 d2.utils.events]:  eta: 0:06:12  iter: 239  total_loss: 0.5274  loss_cls: 0.1476  loss_box_reg: 0.1791  loss_mask: 0.1889  loss_rpn_cls: 0.0004752  loss_rpn_loc: 0.003304    time: 0.4984  last_time: 0.4620  data_time: 0.0103  last_data_time: 0.0083   lr: 0.00011988  max_mem: 2763M
# [10/08 01:15:13 d2.utils.events]:  eta: 0:06:04  iter: 259  total_loss: 0.4995  loss_cls: 0.1322  loss_box_reg: 0.1681  loss_mask: 0.1858  loss_rpn_cls: 0.0006368  loss_rpn_loc: 0.00339    time: 0.4997  last_time: 0.3982  data_time: 0.0155  last_data_time: 0.0144   lr: 0.00012987  max_mem: 2763M
# [10/08 01:15:23 d2.utils.events]:  eta: 0:05:56  iter: 279  total_loss: 0.4293  loss_cls: 0.1222  loss_box_reg: 0.1686  loss_mask: 0.1419  loss_rpn_cls: 0.0007403  loss_rpn_loc: 0.002638    time: 0.5011  last_time: 0.4988  data_time: 0.0172  last_data_time: 0.0136   lr: 0.00013986  max_mem: 2763M
# [10/08 01:15:34 d2.utils.events]:  eta: 0:05:47  iter: 299  total_loss: 0.4345  loss_cls: 0.1177  loss_box_reg: 0.1633  loss_mask: 0.1228  loss_rpn_cls: 0.0004489  loss_rpn_loc: 0.003427    time: 0.5016  last_time: 0.5479  data_time: 0.0144  last_data_time: 0.0225   lr: 0.00014985  max_mem: 2763M
# [10/08 01:15:44 d2.utils.events]:  eta: 0:05:38  iter: 319  total_loss: 0.4003  loss_cls: 0.1148  loss_box_reg: 0.1784  loss_mask: 0.1133  loss_rpn_cls: 0.0009446  loss_rpn_loc: 0.002748    time: 0.5029  last_time: 0.5505  data_time: 0.0161  last_data_time: 0.0085   lr: 0.00015984  max_mem: 2763M
# [10/08 01:15:54 d2.utils.events]:  eta: 0:05:28  iter: 339  total_loss: 0.3636  loss_cls: 0.1069  loss_box_reg: 0.1628  loss_mask: 0.0897  loss_rpn_cls: 4.417e-05  loss_rpn_loc: 0.002883    time: 0.5029  last_time: 0.4883  data_time: 0.0118  last_data_time: 0.0114   lr: 0.00016983  max_mem: 2763M
# [10/08 01:16:04 d2.utils.events]:  eta: 0:05:19  iter: 359  total_loss: 0.458  loss_cls: 0.1363  loss_box_reg: 0.1983  loss_mask: 0.09498  loss_rpn_cls: 0.000555  loss_rpn_loc: 0.003602    time: 0.5031  last_time: 0.5570  data_time: 0.0113  last_data_time: 0.0074   lr: 0.00017982  max_mem: 2763M
# [10/08 01:16:15 d2.utils.events]:  eta: 0:05:10  iter: 379  total_loss: 0.3558  loss_cls: 0.1011  loss_box_reg: 0.1626  loss_mask: 0.09594  loss_rpn_cls: 8.792e-05  loss_rpn_loc: 0.002844    time: 0.5041  last_time: 0.5440  data_time: 0.0127  last_data_time: 0.0070   lr: 0.00018981  max_mem: 2763M
# [10/08 01:16:25 d2.utils.events]:  eta: 0:04:59  iter: 399  total_loss: 0.371  loss_cls: 0.1013  loss_box_reg: 0.1714  loss_mask: 0.08477  loss_rpn_cls: 0.0001062  loss_rpn_loc: 0.003588    time: 0.5033  last_time: 0.4899  data_time: 0.0098  last_data_time: 0.0227   lr: 0.0001998  max_mem: 2763M
# [10/08 01:16:34 d2.utils.events]:  eta: 0:04:49  iter: 419  total_loss: 0.3656  loss_cls: 0.1022  loss_box_reg: 0.1615  loss_mask: 0.08626  loss_rpn_cls: 0.0001536  loss_rpn_loc: 0.003022    time: 0.5027  last_time: 0.4272  data_time: 0.0110  last_data_time: 0.0082   lr: 0.00020979  max_mem: 2763M
# [10/08 01:16:44 d2.utils.events]:  eta: 0:04:39  iter: 439  total_loss: 0.3553  loss_cls: 0.1007  loss_box_reg: 0.1566  loss_mask: 0.08207  loss_rpn_cls: 0.0001283  loss_rpn_loc: 0.003247    time: 0.5023  last_time: 0.4789  data_time: 0.0118  last_data_time: 0.0073   lr: 0.00021978  max_mem: 2763M
# [10/08 01:16:55 d2.utils.events]:  eta: 0:04:29  iter: 459  total_loss: 0.3258  loss_cls: 0.09397  loss_box_reg: 0.1564  loss_mask: 0.07221  loss_rpn_cls: 4.333e-05  loss_rpn_loc: 0.003939    time: 0.5029  last_time: 0.5047  data_time: 0.0131  last_data_time: 0.0323   lr: 0.00022977  max_mem: 2763M
# [10/08 01:17:05 d2.utils.events]:  eta: 0:04:19  iter: 479  total_loss: 0.2971  loss_cls: 0.08191  loss_box_reg: 0.1265  loss_mask: 0.07742  loss_rpn_cls: 5.135e-05  loss_rpn_loc: 0.003476    time: 0.5025  last_time: 0.5369  data_time: 0.0108  last_data_time: 0.0058   lr: 0.00023976  max_mem: 2763M
# [10/08 01:17:15 d2.utils.events]:  eta: 0:04:09  iter: 499  total_loss: 0.3193  loss_cls: 0.08961  loss_box_reg: 0.1306  loss_mask: 0.07735  loss_rpn_cls: 0.0001618  loss_rpn_loc: 0.003369    time: 0.5041  last_time: 0.5255  data_time: 0.0166  last_data_time: 0.0065   lr: 0.00024975  max_mem: 2763M
# [10/08 01:17:26 d2.utils.events]:  eta: 0:04:00  iter: 519  total_loss: 0.293  loss_cls: 0.08074  loss_box_reg: 0.111  loss_mask: 0.06804  loss_rpn_cls: 0.0001058  loss_rpn_loc: 0.004008    time: 0.5047  last_time: 0.5775  data_time: 0.0155  last_data_time: 0.0088   lr: 0.00025974  max_mem: 2763M
# [10/08 01:17:36 d2.utils.events]:  eta: 0:03:49  iter: 539  total_loss: 0.2606  loss_cls: 0.07085  loss_box_reg: 0.0961  loss_mask: 0.07608  loss_rpn_cls: 2.408e-05  loss_rpn_loc: 0.003728    time: 0.5045  last_time: 0.4006  data_time: 0.0145  last_data_time: 0.0105   lr: 0.00026973  max_mem: 2763M
# [10/08 01:17:46 d2.utils.events]:  eta: 0:03:40  iter: 559  total_loss: 0.2258  loss_cls: 0.07231  loss_box_reg: 0.07665  loss_mask: 0.06605  loss_rpn_cls: 9.233e-06  loss_rpn_loc: 0.003416    time: 0.5050  last_time: 0.4988  data_time: 0.0147  last_data_time: 0.0177   lr: 0.00027972  max_mem: 2763M
# [10/08 01:17:56 d2.utils.events]:  eta: 0:03:29  iter: 579  total_loss: 0.1862  loss_cls: 0.05858  loss_box_reg: 0.06128  loss_mask: 0.06793  loss_rpn_cls: 6.11e-06  loss_rpn_loc: 0.00346    time: 0.5043  last_time: 0.3942  data_time: 0.0081  last_data_time: 0.0059   lr: 0.00028971  max_mem: 2763M
# [10/08 01:18:06 d2.utils.events]:  eta: 0:03:20  iter: 599  total_loss: 0.207  loss_cls: 0.06796  loss_box_reg: 0.05694  loss_mask: 0.0674  loss_rpn_cls: 3.797e-06  loss_rpn_loc: 0.003944    time: 0.5043  last_time: 0.5023  data_time: 0.0136  last_data_time: 0.0086   lr: 0.0002997  max_mem: 2763M
# [10/08 01:18:16 d2.utils.events]:  eta: 0:03:10  iter: 619  total_loss: 0.179  loss_cls: 0.05352  loss_box_reg: 0.06131  loss_mask: 0.06358  loss_rpn_cls: 5.1e-06  loss_rpn_loc: 0.002784    time: 0.5041  last_time: 0.4478  data_time: 0.0170  last_data_time: 0.0092   lr: 0.00030969  max_mem: 2763M
# [10/08 01:18:26 d2.utils.events]:  eta: 0:03:00  iter: 639  total_loss: 0.1977  loss_cls: 0.06334  loss_box_reg: 0.06047  loss_mask: 0.06216  loss_rpn_cls: 1.308e-05  loss_rpn_loc: 0.003521    time: 0.5042  last_time: 0.5005  data_time: 0.0086  last_data_time: 0.0067   lr: 0.00031968  max_mem: 2763M
# [10/08 01:18:36 d2.utils.events]:  eta: 0:02:50  iter: 659  total_loss: 0.1855  loss_cls: 0.05469  loss_box_reg: 0.05445  loss_mask: 0.06319  loss_rpn_cls: 1.581e-06  loss_rpn_loc: 0.003514    time: 0.5045  last_time: 0.5426  data_time: 0.0133  last_data_time: 0.0064   lr: 0.00032967  max_mem: 2763M
# [10/08 01:18:46 d2.utils.events]:  eta: 0:02:40  iter: 679  total_loss: 0.1796  loss_cls: 0.04418  loss_box_reg: 0.04478  loss_mask: 0.05732  loss_rpn_cls: 4.282e-06  loss_rpn_loc: 0.002937    time: 0.5043  last_time: 0.5875  data_time: 0.0161  last_data_time: 0.0248   lr: 0.00033966  max_mem: 2763M
# [10/08 01:18:56 d2.utils.events]:  eta: 0:02:29  iter: 699  total_loss: 0.1829  loss_cls: 0.05266  loss_box_reg: 0.05013  loss_mask: 0.0665  loss_rpn_cls: 1.154e-05  loss_rpn_loc: 0.003621    time: 0.5038  last_time: 0.4783  data_time: 0.0082  last_data_time: 0.0061   lr: 0.00034965  max_mem: 2763M
# [10/08 01:19:07 d2.utils.events]:  eta: 0:02:20  iter: 719  total_loss: 0.1622  loss_cls: 0.04612  loss_box_reg: 0.04557  loss_mask: 0.06034  loss_rpn_cls: 2.686e-06  loss_rpn_loc: 0.002843    time: 0.5046  last_time: 0.4793  data_time: 0.0221  last_data_time: 0.0093   lr: 0.00035964  max_mem: 2763M
# [10/08 01:19:17 d2.utils.events]:  eta: 0:02:10  iter: 739  total_loss: 0.1441  loss_cls: 0.03809  loss_box_reg: 0.04242  loss_mask: 0.06627  loss_rpn_cls: 2.373e-05  loss_rpn_loc: 0.003374    time: 0.5047  last_time: 0.4952  data_time: 0.0110  last_data_time: 0.0106   lr: 0.00036963  max_mem: 2763M
# [10/08 01:19:27 d2.utils.events]:  eta: 0:02:00  iter: 759  total_loss: 0.144  loss_cls: 0.04371  loss_box_reg: 0.04351  loss_mask: 0.05963  loss_rpn_cls: 3.86e-06  loss_rpn_loc: 0.002668    time: 0.5050  last_time: 0.4735  data_time: 0.0108  last_data_time: 0.0062   lr: 0.00037962  max_mem: 2763M
# [10/08 01:19:37 d2.utils.events]:  eta: 0:01:50  iter: 779  total_loss: 0.1618  loss_cls: 0.03918  loss_box_reg: 0.05094  loss_mask: 0.06226  loss_rpn_cls: 3.373e-05  loss_rpn_loc: 0.003352    time: 0.5048  last_time: 0.4483  data_time: 0.0136  last_data_time: 0.0061   lr: 0.00038961  max_mem: 2763M
# [10/08 01:19:48 d2.utils.events]:  eta: 0:01:40  iter: 799  total_loss: 0.1323  loss_cls: 0.03266  loss_box_reg: 0.04104  loss_mask: 0.05455  loss_rpn_cls: 1.058e-06  loss_rpn_loc: 0.003122    time: 0.5050  last_time: 0.5276  data_time: 0.0110  last_data_time: 0.0323   lr: 0.0003996  max_mem: 2763M
# [10/08 01:19:58 d2.utils.events]:  eta: 0:01:30  iter: 819  total_loss: 0.1679  loss_cls: 0.03358  loss_box_reg: 0.05122  loss_mask: 0.06791  loss_rpn_cls: 5.517e-06  loss_rpn_loc: 0.003204    time: 0.5054  last_time: 0.5736  data_time: 0.0129  last_data_time: 0.0057   lr: 0.00040959  max_mem: 2763M
# [10/08 01:20:08 d2.utils.events]:  eta: 0:01:20  iter: 839  total_loss: 0.1333  loss_cls: 0.03265  loss_box_reg: 0.04005  loss_mask: 0.05492  loss_rpn_cls: 3.265e-06  loss_rpn_loc: 0.002511    time: 0.5055  last_time: 0.3772  data_time: 0.0122  last_data_time: 0.0067   lr: 0.00041958  max_mem: 2763M
# [10/08 01:20:19 d2.utils.events]:  eta: 0:01:10  iter: 859  total_loss: 0.1406  loss_cls: 0.03457  loss_box_reg: 0.0371  loss_mask: 0.0559  loss_rpn_cls: 2.043e-06  loss_rpn_loc: 0.002639    time: 0.5057  last_time: 0.5123  data_time: 0.0119  last_data_time: 0.0294   lr: 0.00042957  max_mem: 2763M
# [10/08 01:20:28 d2.utils.events]:  eta: 0:01:00  iter: 879  total_loss: 0.1283  loss_cls: 0.02616  loss_box_reg: 0.03547  loss_mask: 0.06321  loss_rpn_cls: 6.849e-06  loss_rpn_loc: 0.002753    time: 0.5052  last_time: 0.5269  data_time: 0.0126  last_data_time: 0.0117   lr: 0.00043956  max_mem: 2763M
# [10/08 01:20:39 d2.utils.events]:  eta: 0:00:50  iter: 899  total_loss: 0.1161  loss_cls: 0.0275  loss_box_reg: 0.03309  loss_mask: 0.04909  loss_rpn_cls: 8.552e-06  loss_rpn_loc: 0.002624    time: 0.5054  last_time: 0.4428  data_time: 0.0123  last_data_time: 0.0078   lr: 0.00044955  max_mem: 2763M
# [10/08 01:20:49 d2.utils.events]:  eta: 0:00:40  iter: 919  total_loss: 0.1187  loss_cls: 0.02369  loss_box_reg: 0.03886  loss_mask: 0.05422  loss_rpn_cls: 3.277e-06  loss_rpn_loc: 0.0038    time: 0.5056  last_time: 0.5750  data_time: 0.0109  last_data_time: 0.0303   lr: 0.00045954  max_mem: 2763M
# [10/08 01:20:59 d2.utils.events]:  eta: 0:00:30  iter: 939  total_loss: 0.1212  loss_cls: 0.02442  loss_box_reg: 0.03319  loss_mask: 0.05384  loss_rpn_cls: 4.587e-06  loss_rpn_loc: 0.002183    time: 0.5053  last_time: 0.4957  data_time: 0.0137  last_data_time: 0.0178   lr: 0.00046953  max_mem: 2763M
# [10/08 01:21:09 d2.utils.events]:  eta: 0:00:20  iter: 959  total_loss: 0.1286  loss_cls: 0.0254  loss_box_reg: 0.03827  loss_mask: 0.05474  loss_rpn_cls: 1.805e-06  loss_rpn_loc: 0.002312    time: 0.5057  last_time: 0.5191  data_time: 0.0176  last_data_time: 0.0208   lr: 0.00047952  max_mem: 2763M
# [10/08 01:21:19 d2.utils.events]:  eta: 0:00:10  iter: 979  total_loss: 0.1162  loss_cls: 0.02279  loss_box_reg: 0.03418  loss_mask: 0.05261  loss_rpn_cls: 2.687e-05  loss_rpn_loc: 0.002795    time: 0.5053  last_time: 0.4462  data_time: 0.0099  last_data_time: 0.0060   lr: 0.00048951  max_mem: 2763M
# [10/08 01:21:31 d2.utils.events]:  eta: 0:00:00  iter: 999  total_loss: 0.1196  loss_cls: 0.02218  loss_box_reg: 0.03526  loss_mask: 0.05419  loss_rpn_cls: 9.866e-07  loss_rpn_loc: 0.00219    time: 0.5056  last_time: 0.4817  data_time: 0.0155  last_data_time: 0.0064   lr: 0.0004995  max_mem: 2763M
# [10/08 01:21:31 d2.engine.hooks]: Overall training speed: 998 iterations in 0:08:24 (0.5056 s / it)
# [10/08 01:21:31 d2.engine.hooks]: Total training time: 0:08:26 (0:00:02 on hooks)
